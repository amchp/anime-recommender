# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('datos/anime_recommendations.csv')

# %%
data.head()
# Out:
#    user_id  0_anime_id  recommendation_1_score  1_anime_id  \
# 0        1       38101               13.914299       39587
# 1       10       40221               13.873494       39587
# 2   100000       40221               13.761553       37991
# 3   100001       38524               13.320706       38101
# 4   100004       39587               15.607419       38524
#
#    recommendation_2_score  2_anime_id  recommendation_3_score  3_anime_id  \
# 0               12.839206       38524               12.241091       40221
# 1               10.900227       38524               10.388511       39195
# 2               12.351057       41353               12.195663       38826
# 3               12.926700       39587               12.877021       41353
# 4               15.328795       38101               13.948916       40221
#
#    recommendation_4_score  4_anime_id  ...  5_anime_id  \
# 0               11.336912       41353  ...       38826
# ...

# %%
sample = pd.read_csv('datos/sample-user-filtered-2023.csv')

# %%
anime_ids = set(sample['anime_id'].unique())
list_anime_ids = np.concatenate([
    data['0_anime_id'], 
    data['1_anime_id'],
    data['2_anime_id'],
    data['3_anime_id'],
    data['4_anime_id'],
    data['5_anime_id'],
    data['6_anime_id'],
    data['7_anime_id'],
    data['8_anime_id'],
    data['9_anime_id'],
])
for anime_id in list_anime_ids:
    assert anime_id in anime_ids
