# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../refined/part-00000-058c1fe6-0687-461a-87b3-cc9ad6e7f344-c000.csv')

# %%
data.head()
# Out:
#    user_id  0_anime_id  recommendation_1_score  1_anime_id  \
# 0        0       44511               11.508946       35054
# 1        1       44511               11.525372       35054
# 2       10       44511               12.273844       35054
# 3     1000       42916                9.161975       43772
# 4    10000       44511               11.470617       35054
#
#    recommendation_2_score  2_anime_id  recommendation_3_score  3_anime_id  \
# 0               11.197250       35058               10.717719       35035
# 1               11.334157       35058               10.784395       35035
# 2               11.073846       35058               10.564326       35035
# 3                8.992080       41218                8.502162       42485
# 4               10.138788       35058                9.731273       41674
#
#    recommendation_4_score  4_anime_id  ...  5_anime_id  \
# 0               10.382718       33894  ...       31004
# 1               10.462463       35055  ...       42916
# 2               10.366351       36322  ...       41674
# 3                8.243172       40554  ...       34531
# 4                9.669159         820  ...       36322
#
#    recommendation_6_score  6_anime_id  recommendation_7_score  7_anime_id  \
# 0                9.633505       26293                9.614492       39486
# 1                9.487168       39486                9.413850       26293
# 2               10.208136         820                9.918789        3786
# 3                8.120483       35609                7.976732       35054
# 4                9.642041        2921                9.566600       35035
#
#    recommendation_8_score  8_anime_id  recommendation_9_score  9_anime_id  \
# 0                9.554270       28023                9.448798       42916
# 1                9.326929       40028                9.296944       38524
# 2                9.750770        2921                9.706575       41277
# 3                7.968999       48418                7.942654       48417
# 4                9.514440       45556                9.436576       24701
#
#    recommendation_10_score
# 0                 9.362709
# 1                 9.236201
# 2                 9.675491
# 3                 7.942654
# 4                 9.226246
#
# [5 rows x 21 columns]

# %%
sample = pd.read_csv('datos/user-filtered.csv')

# %%
anime_ids = set(sample['anime_id'].unique())
list_anime_ids = np.concatenate([
    data['0_anime_id'], 
    data['1_anime_id'],
    data['2_anime_id'],
    data['3_anime_id'],
    data['4_anime_id'],
    data['5_anime_id'],
    data['6_anime_id'],
    data['7_anime_id'],
    data['8_anime_id'],
    data['9_anime_id'],
])
for anime_id in list_anime_ids:
    assert anime_id in anime_ids
